# %%
from google.colab import drive
drive.mount('/content/gdrive')

# change to working tensorflow directory on the drive
# %cd '/content/gdrive/MyDrive/word_data'
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/word_data

# %%
#importing libraries
import os
import librosa
import IPython.display as ipd
import matplotlib.pyplot as plt
import numpy as np
import warnings
# %matplotlib inline
from keras.layers import Dense, Dropout, Flatten, Conv1D, Input, MaxPooling1D
from keras.models import Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K
from keras.models import Sequential
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from keras.utils import np_utils
import random
from sklearn import metrics
import keras
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.layers import BatchNormalization,Activation,Dropout,LSTM

warnings.filterwarnings("ignore")

# %% [markdown]
# ### Classes

# %%
class DataConversion:
  def __init__(self,root):
    self.root=root
    self.all_wave = []
    self.all_label = []
  def DataToWave(self,number_of_samples): 
    for label in labels:
        waves = [f for f in os.listdir(self.root + '/'+ label) if f.endswith('.wav')]
        for wav in waves[:number_of_sample]:
            samples, sample_rate = librosa.load(self.root + '/' + label + '/' + wav, sr = 16000)
            samples = librosa.resample(samples, sample_rate, 8000)
            if(len(sample)== 8000): 
                all_wave.append(samples)
                all_label.append(label)
    return self.all_wave,self.all_label        

class Models:
  def cnn_model(self):
    inputs = Input(shape=(8000,1))
    #First Conv1D layer
    conv = Conv1D(8,13, padding='same', activation='relu', strides=1)(inputs)
    conv = MaxPooling1D(3)(conv)
    conv = Dropout(0.3)(conv)

    #Second Conv1D layer
    conv = Conv1D(16, 11, padding='same', activation='relu', strides=1)(conv)
    conv = MaxPooling1D(3)(conv)
    conv = Dropout(0.3)(conv)

    #Third Conv1D layer
    conv = Conv1D(32, 9, padding='same', activation='relu', strides=1)(conv)
    conv = MaxPooling1D(3)(conv)
    conv = Dropout(0.3)(conv)

    #Fourth Conv1D layer
    conv = Conv1D(64, 7, padding='same', activation='relu', strides=1)(conv)
    conv = MaxPooling1D(3)(conv)
    conv = Dropout(0.3)(conv)

    #Fourth Conv1D layer
    conv = Conv1D(128, 5, padding='same', activation='relu', strides=1)(conv)
    conv = MaxPooling1D(3)(conv)
    conv = Dropout(0.3)(conv)


    #Flatten layer
    conv = Flatten()(conv)

    #Dense Layer 1
    conv = Dense(256, activation='relu')(conv)
    conv = Dropout(0.3)(conv)

    #Dense Layer 2
    conv = Dense(128, activation='relu')(conv)
    conv = Dropout(0.3)(conv)


    classification_output = keras.layers.Dense(len(labels), activation="softmax")(conv)

    self.model = Model(inputs, outputs=classification_output)#outputs)    
    return self.model , self.model.summary()
  
  def cnn_compile(self):
    return self.model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
  
  def cnn_fit(self,x_tr,y_tr):
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20, min_delta=0.0001) 
    mc = ModelCheckpoint('best_model.hdf5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    return self.model.fit(x_tr, y_tr ,epochs=100, batch_size=32,callbacks=[es,mc], validation_data=(x_val,y_val))
  def model_save(self,path):
    return self.model.save(path)

class Model_test:
  def cnn_predict(self,audio):
    prob=self.model.predict(audio.reshape(1,8000,1))
    index=np.argmax(prob[0])
    return classes[index]
  def evaluation(self,x_test,y_test,batch_size=48):
    results = self.model.evaluate(x_test, y_test, batch_size)
    return results

class Model_accuracy:
  def accuracy():
    plt.plot(history.history['loss'], label='train')
    plt.plot(history.history['val_loss'], label='test')
    plt.legend()
    return plt.show()

class DataPrepration:
  def __init__(self,all_label):
    self.all_label = all_label
  def labels_encoder(self):
    le = LabelEncoder()
    y=le.fit_transform(self.all_label)
    classes= list(le.classes_)
    return classes
  def spliting_data(self,test_size,random_state,shuffle):
    x_tr, x_val, y_tr, y_val = train_test_split(np.array(all_wave),
                                                test_size,
                                                np.array(y),
                                                random_state,
                                                shuffle,stratify=y)
    return x_tr,x_val,y_tr,y_val

# %%
#main
sample_rate = 16000 
root = '/content/gdrive/MyDrive/word_data/kaggle_original_data/train/audio'
number_of_sample = 600   #datavalues

labels=['bed', 'cat', 'down', 'left', 'no', 'right', 'seven', 'stop', 'yes', 'up']

all_wave = []
all_label = []
for label in labels:
    waves = [f for f in os.listdir(root + '/'+ label) if f.endswith('.wav')]
    for wav in waves[:number_of_sample]:
        samples, sample_rate = librosa.load(root + '/' + label + '/' + wav, sr = 16000)
        samples = librosa.resample(samples, sample_rate, 8000)
        if(len(samples)== 8000): 
            all_wave.append(samples)
            all_label.append(label)
#printing all labels
le = LabelEncoder()
y=le.fit_transform(all_label)
classes= list(le.classes_)

#DP=DataPrepration(all_label)
#DP.label_encoder()

print(classes)
y=np_utils.to_categorical(y, num_classes=len(labels))
all_wave = np.array(all_wave).reshape(-1,8000,1)

x_tr, x_val, y_tr, y_val = train_test_split(np.array(all_wave),np.array(y),stratify=y,test_size = 0.2,random_state=777,shuffle=True)

model=Models()
model.cnn_model()
model.cnn_compile()
history=model.cnn_fit(x_tr, y_tr)

#Accuracy Graph
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()
# Out:
# ['bed', 'cat', 'down', 'left', 'no', 'right', 'seven', 'stop', 'up', 'yes']
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 8000, 1)]         0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 8000, 8)           112
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 2666, 8)           0
# _________________________________________________________________
# dropout (Dropout)            (None, 2666, 8)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 2666, 16)          1424
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 888, 16)           0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 888, 16)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 888, 32)           4640
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 296, 32)           0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 296, 32)           0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 296, 64)           14400
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 98, 64)            0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 98, 64)            0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 98, 128)           41088
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 32, 128)           0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 32, 128)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               1048832
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 1,144,682
# Trainable params: 1,144,682
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 337/337 [==============================] - 86s 252ms/step - loss: 2.2665 - accuracy: 0.1273 - val_loss: 1.9124 - val_accuracy: 0.2537
#
# Epoch 00001: val_accuracy improved from -inf to 0.25371, saving model to gdrive/MyDrive/word_data/best_model.hdf5
# Epoch 2/100
# 337/337 [==============================] - 88s 260ms/step - loss: 1.8711 - accuracy: 0.2839 - val_loss: 1.6191 - val_accuracy: 0.3934
#
# Epoch 00002: val_accuracy improved from 0.25371 to 0.39339, saving model to gdrive/MyDrive/word_data/best_model.hdf5
# Epoch 3/100
# 337/337 [==============================] - 84s 251ms/step - loss: 1.6126 - accuracy: 0.3810 - val_loss: 1.3943 - val_accuracy: 0.4907
#
# Epoch 00003: val_accuracy improved from 0.39339 to 0.49071, saving model to gdrive/MyDrive/word_data/best_model.hdf5
# Epoch 4/100
# 337/337 [==============================] - 85s 251ms/step - loss: 1.4170 - accuracy: 0.4665 - val_loss: 1.1977 - val_accuracy: 0.5672
#
# Epoch 00004: val_accuracy improved from 0.49071 to 0.56724, saving model to gdrive/MyDrive/word_data/best_model.hdf5
# Epoch 5/100
# 337/337 [==============================] - 85s 252ms/step - loss: 1.2708 - accuracy: 0.5197 - val_loss: 1.1082 - val_accuracy: 0.5988
#
# Epoch 00005: val_accuracy improved from 0.56724 to 0.59881, saving model to gdrive/MyDrive/word_data/best_model.hdf5
# Epoch 6/100
# 337/337 [==============================] - 85s 253ms/step - loss: 1.1926 - accuracy: 0.5649 - val_loss: 1.0378 - val_accuracy: 0.6386
#
# Epoch 00006: val_accuracy improved from 0.59881 to 0.63856, saving model to gdrive/MyDrive/word_data/best_model.hdf5
# Epoch 7/100
# 337/337 [==============================] - 85s 251ms/step - loss: 1.0890 - accuracy: 0.6054 - val_loss: 0.9988 - val_accuracy: 0.6616
#
# Epoch 00007: val_accuracy improved from 0.63856 to 0.66159, saving model to gdrive/MyDrive/word_data/best_model.hdf5
# Epoch 8/100
# 337/337 [==============================] - 85s 252ms/step - loss: 1.0161 - accuracy: 0.6411 - val_loss: 0.8971 - val_accuracy: 0.7047
#
# Epoch 00008: val_accuracy improved from 0.66159 to 0.70468, saving model to gdrive/MyDrive/word_data/best_model.hdf5
# Epoch 9/100
# 337/337 [==============================] - 89s 265ms/step - loss: 0.9510 - accuracy: 0.6650 - val_loss: 0.8734 - val_accuracy: 0.6969
#
# Epoch 00009: val_accuracy did not improve from 0.70468
# Epoch 10/100
# 337/337 [==============================] - 85s 253ms/step - loss: 0.8694 - accuracy: 0.6894 - val_loss: 0.7831 - val_accuracy: 0.7493
#
# Epoch 00010: val_accuracy improved from 0.70468 to 0.74926, saving model to gdrive/MyDrive/word_data/best_model.hdf5
# Epoch 11/100
# 337/337 [==============================] - 85s 252ms/step - loss: 0.8032 - accuracy: 0.7237 - val_loss: 0.7659 - val_accuracy: 0.7559
#
# Epoch 00011: val_accuracy improved from 0.74926 to 0.75594, saving model to gdrive/MyDrive/word_data/best_model.hdf5
# Epoch 12/100
# 337/337 [==============================] - 85s 253ms/step - loss: 0.7481 - accuracy: 0.7429 - val_loss: 0.7315 - val_accuracy: 0.7515
#
# Epoch 00012: val_accuracy did not improve from 0.75594
# Epoch 13/100
# 337/337 [==============================] - 85s 251ms/step - loss: 0.6523 - accuracy: 0.7830 - val_loss: 0.5927 - val_accuracy: 0.8135
#
# Epoch 00013: val_accuracy improved from 0.75594 to 0.81352, saving model to gdrive/MyDrive/word_data/best_model.hdf5
# Epoch 14/100
# 337/337 [==============================] - 84s 249ms/step - loss: 0.6201 - accuracy: 0.7944 - val_loss: 0.6126 - val_accuracy: 0.7972
#
# Epoch 00014: val_accuracy did not improve from 0.81352
# Epoch 15/100
# 337/337 [==============================] - 84s 249ms/step - loss: 0.5936 - accuracy: 0.8073 - val_loss: 0.5534 - val_accuracy: 0.8258
#
# Epoch 00015: val_accuracy improved from 0.81352 to 0.82578, saving model to gdrive/MyDrive/word_data/best_model.hdf5
# Epoch 16/100
# 337/337 [==============================] - 89s 263ms/step - loss: 0.5483 - accuracy: 0.8208 - val_loss: 0.5032 - val_accuracy: 0.8440
#
# Epoch 00016: val_accuracy improved from 0.82578 to 0.84398, saving model to gdrive/MyDrive/word_data/best_model.hdf5
# Epoch 17/100
# 337/337 [==============================] - 85s 253ms/step - loss: 0.4812 - accuracy: 0.8425 - val_loss: 0.5281 - val_accuracy: 0.8317
#
# Epoch 00017: val_accuracy did not improve from 0.84398
# Epoch 18/100
# 337/337 [==============================] - 85s 252ms/step - loss: 0.4793 - accuracy: 0.8417 - val_loss: 0.6066 - val_accuracy: 0.8139
#
# Epoch 00018: val_accuracy did not improve from 0.84398
# Epoch 19/100
# 337/337 [==============================] - 85s 253ms/step - loss: 0.4484 - accuracy: 0.8560 - val_loss: 0.4856 - val_accuracy: 0.8455
#
# Epoch 00019: val_accuracy improved from 0.84398 to 0.84547, saving model to gdrive/MyDrive/word_data/best_model.hdf5
# Epoch 20/100
# 337/337 [==============================] - 85s 253ms/step - loss: 0.4256 - accuracy: 0.8653 - val_loss: 0.4888 - val_accuracy: 0.8510
#
# Epoch 00020: val_accuracy improved from 0.84547 to 0.85104, saving model to gdrive/MyDrive/word_data/best_model.hdf5
# Epoch 21/100
# 337/337 [==============================] - 85s 253ms/step - loss: 0.4254 - accuracy: 0.8634 - val_loss: 0.4384 - val_accuracy: 0.8637
#
# Epoch 00021: val_accuracy improved from 0.85104 to 0.86367, saving model to gdrive/MyDrive/word_data/best_model.hdf5
# Epoch 22/100
# 337/337 [==============================] - 85s 253ms/step - loss: 0.3755 - accuracy: 0.8721 - val_loss: 0.4606 - val_accuracy: 0.8562
#
# Epoch 00022: val_accuracy did not improve from 0.86367
# Epoch 23/100
# 337/337 [==============================] - 85s 253ms/step - loss: 0.3982 - accuracy: 0.8717 - val_loss: 0.5560 - val_accuracy: 0.8291
#
# Epoch 00023: val_accuracy did not improve from 0.86367
# Epoch 24/100
# 337/337 [==============================] - 88s 262ms/step - loss: 0.3603 - accuracy: 0.8792 - val_loss: 0.4516 - val_accuracy: 0.8614
#
# Epoch 00024: val_accuracy did not improve from 0.86367
# Epoch 25/100
# 337/337 [==============================] - 85s 253ms/step - loss: 0.3802 - accuracy: 0.8747 - val_loss: 0.4312 - val_accuracy: 0.8652
#
# Epoch 00025: val_accuracy improved from 0.86367 to 0.86516, saving model to gdrive/MyDrive/word_data/best_model.hdf5
# Epoch 26/100
# 337/337 [==============================] - 85s 252ms/step - loss: 0.3371 - accuracy: 0.8919 - val_loss: 0.4831 - val_accuracy: 0.8455
#
# Epoch 00026: val_accuracy did not improve from 0.86516
# Epoch 27/100
# 337/337 [==============================] - 85s 253ms/step - loss: 0.3432 - accuracy: 0.8891 - val_loss: 0.4047 - val_accuracy: 0.8756
#
# Epoch 00027: val_accuracy improved from 0.86516 to 0.87556, saving model to gdrive/MyDrive/word_data/best_model.hdf5
# Epoch 28/100
# 337/337 [==============================] - 85s 253ms/step - loss: 0.3366 - accuracy: 0.8899 - val_loss: 0.4464 - val_accuracy: 0.8652
#
# Epoch 00028: val_accuracy did not improve from 0.87556
# Epoch 29/100
# 337/337 [==============================] - 85s 252ms/step - loss: 0.3295 - accuracy: 0.8939 - val_loss: 0.4187 - val_accuracy: 0.8715
#
# Epoch 00029: val_accuracy did not improve from 0.87556
# Epoch 30/100
# 337/337 [==============================] - 85s 252ms/step - loss: 0.3463 - accuracy: 0.8852 - val_loss: 0.4353 - val_accuracy: 0.8666
#
# Epoch 00030: val_accuracy did not improve from 0.87556
# Epoch 31/100
# 337/337 [==============================] - 88s 260ms/step - loss: 0.3073 - accuracy: 0.8988 - val_loss: 0.4424 - val_accuracy: 0.8681
#
# Epoch 00031: val_accuracy did not improve from 0.87556
# Epoch 32/100
# 337/337 [==============================] - 85s 253ms/step - loss: 0.2951 - accuracy: 0.9041 - val_loss: 0.4314 - val_accuracy: 0.8700
#
# Epoch 00032: val_accuracy did not improve from 0.87556
# Epoch 33/100
# 337/337 [==============================] - 86s 254ms/step - loss: 0.2855 - accuracy: 0.9040 - val_loss: 0.4445 - val_accuracy: 0.8696
#
# Epoch 00033: val_accuracy did not improve from 0.87556
# Epoch 34/100
# 337/337 [==============================] - 86s 255ms/step - loss: 0.2838 - accuracy: 0.9119 - val_loss: 0.4545 - val_accuracy: 0.8592
#
# Epoch 00034: val_accuracy did not improve from 0.87556
# Epoch 35/100
# 337/337 [==============================] - 86s 254ms/step - loss: 0.2786 - accuracy: 0.9096 - val_loss: 0.4723 - val_accuracy: 0.8551
#
# Epoch 00035: val_accuracy did not improve from 0.87556
# Epoch 36/100
# 337/337 [==============================] - 85s 253ms/step - loss: 0.2964 - accuracy: 0.9042 - val_loss: 0.4137 - val_accuracy: 0.8782
#
# Epoch 00036: val_accuracy improved from 0.87556 to 0.87816, saving model to gdrive/MyDrive/word_data/best_model.hdf5
# Epoch 37/100
# 337/337 [==============================] - 85s 253ms/step - loss: 0.2733 - accuracy: 0.9099 - val_loss: 0.4332 - val_accuracy: 0.8700
#
# Epoch 00037: val_accuracy did not improve from 0.87816
# Epoch 38/100
# 337/337 [==============================] - 88s 261ms/step - loss: 0.2684 - accuracy: 0.9119 - val_loss: 0.4342 - val_accuracy: 0.8785
#
# Epoch 00038: val_accuracy improved from 0.87816 to 0.87853, saving model to gdrive/MyDrive/word_data/best_model.hdf5
# Epoch 39/100
# 337/337 [==============================] - 85s 254ms/step - loss: 0.2688 - accuracy: 0.9111 - val_loss: 0.4414 - val_accuracy: 0.8622
#
# Epoch 00039: val_accuracy did not improve from 0.87853
# Epoch 40/100
# 337/337 [==============================] - 85s 253ms/step - loss: 0.2612 - accuracy: 0.9154 - val_loss: 0.4290 - val_accuracy: 0.8756
#
# Epoch 00040: val_accuracy did not improve from 0.87853
# Epoch 41/100
# 337/337 [==============================] - 86s 254ms/step - loss: 0.2561 - accuracy: 0.9175 - val_loss: 0.4251 - val_accuracy: 0.8726
#
# Epoch 00041: val_accuracy did not improve from 0.87853
# Epoch 42/100
# 337/337 [==============================] - 86s 254ms/step - loss: 0.2451 - accuracy: 0.9207 - val_loss: 0.4558 - val_accuracy: 0.8711
#
# Epoch 00042: val_accuracy did not improve from 0.87853
# Epoch 43/100
# 337/337 [==============================] - 86s 254ms/step - loss: 0.2725 - accuracy: 0.9143 - val_loss: 0.4376 - val_accuracy: 0.8748
#
# Epoch 00043: val_accuracy did not improve from 0.87853
# Epoch 44/100
# 337/337 [==============================] - 85s 254ms/step - loss: 0.2327 - accuracy: 0.9246 - val_loss: 0.4838 - val_accuracy: 0.8626
#
# Epoch 00044: val_accuracy did not improve from 0.87853
# Epoch 45/100
# 337/337 [==============================] - 88s 261ms/step - loss: 0.2458 - accuracy: 0.9192 - val_loss: 0.4514 - val_accuracy: 0.8756
#
# Epoch 00045: val_accuracy did not improve from 0.87853
# Epoch 46/100
# 337/337 [==============================] - 85s 253ms/step - loss: 0.2394 - accuracy: 0.9220 - val_loss: 0.4182 - val_accuracy: 0.8763
#
# Epoch 00046: val_accuracy did not improve from 0.87853
# Epoch 47/100
# 337/337 [==============================] - 85s 253ms/step - loss: 0.2473 - accuracy: 0.9204 - val_loss: 0.4210 - val_accuracy: 0.8689
#
# Epoch 00047: val_accuracy did not improve from 0.87853
# Epoch 00047: early stopping

# %%
model.model_save('/content/gdrive/MyDrive/word_data/model_DL.h5')

# %%
from tensorflow.keras.models import load_model
loded=load_model('/content/gdrive/MyDrive/word_data/model_DL.h5')

# %%
test=loded.evaluate(x_val,y_val)
print("Test Accuracy: " , (test[1]*100),'%')
# Out:
# 85/85 [==============================] - 6s 69ms/step - loss: 0.4210 - accuracy: 0.8689
# Test Accuracy:  86.8870735168457 %

# %%
train=loded.evaluate(x_tr,y_tr)
print("Test Accuracy: " , (train[1]*100),'%')
# Out:
# 135/135 [==============================] - 10s 73ms/step - loss: 0.0760 - accuracy: 0.9816
# Test Accuracy:  98.15979599952698 %
